# %% [markdown]
# # Sentiment Analysis of Amazon reviews

# %% [markdown]
# #### Dataset:
# http://deepyeti.ucsd.edu/jianmo/amazon/index.html
#
# Software reviews (459,436 reviews) metadata (26,815 products)

# %% [markdown]
# ### Evaluating customer reviews on software products sold on Amazon.

# %%
import pandas as pd
import numpy as np

# %%
# load dataset
df = pd.read_json (r'Software.json', lines=True)

# %%
df.shape
# Out:
# (459436, 12)

# %%
df.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        4      True  03 11, 2014  A240ORQ2LF9LUI  0077613252
# 1        4      True  02 23, 2014  A1YCCU0YRLS0FE  0077613252
# 2        1      True  02 17, 2014  A1BJHRQDYVAY2J  0077613252
# 3        3      True  02 17, 2014   APRDVZ6QBIQXT  0077613252
# 4        5     False  10 14, 2013  A2JZTTBSLS1QXV  0077775473
#
#                         style         reviewerName  \
# 0  {'Format:': ' Loose Leaf'}           Michelle W
# 1  {'Format:': ' Loose Leaf'}  Rosalind White Ames
# 2  {'Format:': ' Loose Leaf'}       Allan R. Baker
# 3  {'Format:': ' Loose Leaf'}                 Lucy
# 4                         NaN            Albert V.
#
#                                           reviewText  \
# 0  The materials arrived early and were in excell...
# 1  I am really enjoying this book with the worksh...
# 2  IF YOU ARE TAKING THIS CLASS DON"T WASTE YOUR ...
# 3  This book was missing pages!!! Important pages...
# 4  I have used LearnSmart and can officially say ...
#
#                          summary  unixReviewTime vote image
# 0                 Material Great      1394496000  NaN   NaN
# 1                         Health      1393113600  NaN   NaN
# 2             ARE YOU KIDING ME?      1392595200    7   NaN
# 3                missing pages!!      1392595200    3   NaN
# 4  Best study product out there!      1381708800  NaN   NaN

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# Understanding the data provided and identifying the data needed for evaluation.
# Deciding which values need to be excluded.

# %%
# Empty values in each column 
df.isnull().sum()
# Out:
# overall                0
# verified               0
# reviewTime             0
# reviewerID             0
# asin                   0
# style             225035
# reviewerName          24
# reviewText            66
# summary               56
# unixReviewTime         0
# vote              331583
# image             457928
# dtype: int64

# %%
df["verified"].count()
# Out:
# 459436

# %%
# Number of unverified purchases 
df.verified[df.verified==False].count()
# Out:
# 150091

# %% [markdown]
# As 150091 unverified purchases would be too many to exclude, it is better to keep them.

# %%
#number of individual reviewers
df['reviewerID'].nunique()
# Out:
# 375142

# %%
#Timeframe of the dataset

print (df.reviewTime.min())
print (df.reviewTime.max())
# Out:
# 01 1, 2000
# 12 9, 2017

# %%
#number of products reviewed
df['asin'].nunique()
# Out:
# 21663

# %%
#Stars rating
df['overall'].value_counts()
# Out:
# 5    212452
# 1    102548
# 4     73596
# 3     39395
# 2     31445
# Name: overall, dtype: int64

# %% [markdown]
# The given data provides a wide range of product evaluation and is surely interesting to see the results of the analysis.

# %% [markdown]
# ### Data preparation

# %% [markdown]
# For the language analysis there will be no need to keep entries without the actual text. Therefore it would be best to drop the NaN values.
#
# reviewText            66
#
# summary               56

# %%
# Null values
df.isnull().sum()
# Out:
# overall                0
# verified               0
# reviewTime             0
# reviewerID             0
# asin                   0
# style             225030
# reviewerName          24
# reviewText            60
# summary               50
# unixReviewTime         0
# vote              331577
# image             457922
# dtype: int64

# %%
#Taking a closer look at the NaN values before deleting

df[df['reviewText'].isna()]
# Out:
#         overall  verified   reviewTime      reviewerID        asin  \
# 54226         5      True  06 10, 2012  A1J59HUIE22VK6  B000XYUSMI
# 62732         5      True  06 10, 2012  A1J59HUIE22VK6  B000XYUSMI
# 70273         4      True  07 11, 2014  A16YPRS120VV5R  B001B057U6
# 86543         5      True   05 3, 2018   A461O3V81H0GY  B002IKIHEG
# 86904         5      True  11 19, 2014   A4EFRSUB5W8Y7  B002IKIHEG
# ...         ...       ...          ...             ...         ...
# 453877        5      True   07 5, 2018  A1HUGNK5PTQBV6  B0130P9E0I
# 454201        5      True   04 2, 2018  A1K19WSFBM8C6C  B013EXF9T6
# 456027        1      True  07 18, 2018    AUGXBAROCF67  B01617VPUY
# 456446        5     False  03 28, 2016  A109P5888SV0N1  B016RRQD5A
# 457789        5      True   09 8, 2016  A2XVIPCC60UA6W  B01B8ORCF2
#
#                                style     reviewerName reviewText  \
# 54226                            NaN            chale        NaN
# 62732                            NaN            chale        NaN
# 70273                            NaN        Boon Kiat        NaN
# 86543            {'Format:': ' DVD'}              joe        NaN
# 86904   {'Format:': ' Amazon Video'}         Marlin G        NaN
# ...                              ...              ...        ...
# 453877                           NaN  Amazon Customer        NaN
# 454201                           NaN         Joe Mama        NaN
# 456027  {'Platform:': ' PC/MacDisc'}              JLO        NaN
# 456446                           NaN              a b        NaN
# 457789                           NaN  Amazon Customer        NaN
#
#                                                   summary  unixReviewTime  \
# 54226                                      hallmark/kodak      1339286400
# 62732                                      hallmark/kodak      1339286400
# 70273                                          Four Stars      1405036800
# 86543                                          Five Stars      1525305600
# 86904                                          Five Stars      1416355200
# ...                                                   ...             ...
# 453877                                                NaN      1530748800
# 454201                                         Five Stars      1522627200
# 456027  They sent a basic knowingly . After advertisin...      1531872000
# 456446                                         Five Stars      1459123200
# 457789                                    Buy this manual      1473292800
#
#        vote                                              image
# 54226   NaN                                                NaN
# 62732   NaN                                                NaN
# 70273   NaN                                                NaN
# 86543   NaN  [https://images-na.ssl-images-amazon.com/image...
# 86904   NaN                                                NaN
# ...     ...                                                ...
# 453877  NaN                                                NaN
# 454201  NaN                                                NaN
# 456027  NaN  [https://images-na.ssl-images-amazon.com/image...
# 456446  NaN                                                NaN
# 457789  NaN  [https://images-na.ssl-images-amazon.com/image...
#
# [66 rows x 12 columns]

# %%
# NaN values in the summary column
df[df['summary'].isna()]
# Out:
#         overall  verified   reviewTime      reviewerID        asin  \
# 5467          5      True  08 29, 2007   AGZDSR4R8SA2S  B000050ZRE
# 6116          4     False   03 7, 2002  A15S4XW3CRISZ5  B00005AFI4
# 16504         5      True  08 29, 2007   AGZDSR4R8SA2S  B0001FS9NE
# 31221         5      True  08 29, 2007   AGZDSR4R8SA2S  B000EORV8Q
# 51457         5      True  08 29, 2007   AGZDSR4R8SA2S  B0000AZJY6
# 56135         5      True  06 27, 2008   ALD8MK1VA5BQK  B0013OAHTG
# 59963         5      True  08 29, 2007   AGZDSR4R8SA2S  B0000AZJY6
# 64641         5      True  06 27, 2008   ALD8MK1VA5BQK  B0013OAHTG
# 68884         5      True  04 11, 2015   AT71IDXZWU9EG  B001AMHWP8
# 128674        3      True  12 10, 2013  A15NSG16V2LJ8N  B005S4Y13K
# 135871        5      True  10 24, 2014  A25ZR2IDDHIKTE  B006T4SQG6
# 176437        5      True  12 13, 2017  A10PEN90UAB79P  B00CTTEKJW
# 178030        5      True  12 17, 2016  A2H8Y1RHVR1L82  B00CTTEKJW
# 199350        5      True  06 19, 2014  A1GACWHNEXH1TP  B00EDSI8HW
# 203669        5      True  09 19, 2014  A33PV5KUXCG7J6  B00EOI2SR2
# 210292        1      True  12 10, 2014  A3S6UF2MVQL8GT  B00EZPXYP4
# 212788        5      True  03 19, 2015  A1AOBJNNC4817V  B00EZQYC8G
# 218590        4      True   03 3, 2014   AB9L142W5NLD4  B00F8K9KZS
# 233152        4      True  04 18, 2017  A1VRTHL4CSDQMC  B00GRFIIHO
# 233182        1      True  03 15, 2017  A2LOXUYFPBOQ3K  B00GRFIIHO
# 243477        5     False  04 10, 2014   AWIIDKKH1K2AM  B00IR8OOPE
# 247942        1      True  08 30, 2017  A3UV6XDEOF3CVV  B00L13X6QA
# 250507        5      True  12 13, 2014  A2XBS5867IZNBP  B00LC9UU6C
# 252000        1      True  05 19, 2016  A1SAD98736A4D3  B00LHTR8IK
# 261433        1     False   11 3, 2014   AVDRZ7L03M30U  B00MCLG0UY
# 267021        1      True   04 9, 2015  A129WL0NDBPEV4  B00MUTB2SS
# 278156        3      True  01 19, 2015   AGFN7IEEKV9JR  B00NG7JU4Q
# 285129        1     False  02 12, 2015  A1PF68MAHHNG8J  B00NG7JVSQ
# 289677        5      True  01 23, 2017  A3JO4UP0M7NPTV  B00OMQLNJK
# 312590        5      True  11 27, 2015  A3C9I1G3V10QCC  B00UB76290
# 313722        2      True  07 29, 2015  A2VLN27NRJ5VY9  B00UB76290
# 316636        1      True  10 15, 2016  A3S7TVFGQ5BI9W  B00YNJJMF8
# 318638        3      True  08 13, 2017  A1Q7N8R35GRN29  B01019T6O0
# 321775        5      True  04 26, 2016  A28J2GWYZWAFS4  B011W122FQ
# 328270        5      True   12 9, 2016  A1CRDIRXWXJOI9  B013CTP2T4
# 330604        2      True  06 16, 2016  A1F2ZUYTVAL34K  B013X957AM
# 330880        5      True   09 5, 2017  A30U0YOQ9O01AD  B0143HYNI0
# 337546        5      True  04 15, 2017   AAWCUD3HKHFIA  B0153V62P2
# 344179        1      True  11 16, 2017   A6OEENDD95UPH  B015NN1E0S
# 362289        5      True  04 28, 2017   AK0ZHOAQVBEV9  B01F70HGA4
# 364755        5      True  04 25, 2017   AXPAXQ1BQNJRK  B01HAP47PQ
# 365655        4      True  10 24, 2015  A3LCH99CZ5YEJJ  1563826224
# 370974        1     False  08 10, 2006  A1T7U0ZP3JL81I  B00004WCEV
# 373276        1      True  10 30, 2017  A3IUJUS78CNMLG  B00005LBVS
# 376001        5      True  07 16, 2015  A3DHCIDXXT0GO8  B000060NVS
# 383442        1     False  04 14, 2006   AZAOKMGB04JRA  B00018ZRH2
# 388610        2      True   02 6, 2014   A2MZBDIIR6QVF  B0007IOVLE
# 399971        1     False  11 21, 2008  A28E3F0LAVO6AA  B000KH732Q
# 406664        3      True  09 19, 2017   AOYYG3LEUYG8D  B0012H8U9S
# 421085        1      True   02 5, 2015  A1CLMYQJ2PV4RI  B004EP3HJI
# 434276        5      True  05 24, 2015  A1DL0SO4T55VJL  B00BSGET02
# 442679        5      True   07 5, 2018  A1HUGNK5PTQBV6  B00ISC279O
# 446926        5      True  07 15, 2018  A2GYSLLCSEG98H  B00N9MUV96
# 449948        5      True   01 8, 2018   A7OZ1DQQ3FIGR  B0068DGSRM
# 453877        5      True   07 5, 2018  A1HUGNK5PTQBV6  B0130P9E0I
# 457408        5     False  06 11, 2016   A5AKQJX4XEN6M  B00106XE8I
#
#                                     style        reviewerName  \
# 5467                                  NaN       Kelly Carlson
# 6116                                  NaN      Andre Da Costa
# 16504                                 NaN       Kelly Carlson
# 31221                                 NaN       Kelly Carlson
# 51457                                 NaN       Kelly Carlson
# 56135                                 NaN            G. Sabio
# 59963                                 NaN       Kelly Carlson
# 64641                                 NaN            G. Sabio
# 68884                                 NaN            jonathan
# 128674  {'Format:': ' Software Download'}               NickR
# 135871                                NaN               David
# 176437               {'Platform:': ' PC'}            Ian Tice
# 178030               {'Platform:': ' PC'}      Daniel Mercado
# 199350                                NaN              daliso
# 203669  {'Format:': ' Software Download'}             Jenifer
# 210292          {'Platform:': ' PC Disc'}          Glen Yates
# 212788      {'Platform:': ' PC Download'}         cantomagica
# 218590      {'Platform:': ' PC/Mac Disc'}        K2enterprise
# 233152              {'Platform:': ' Mac'}               Edith
# 233182              {'Platform:': ' Mac'}     Amazon Customer
# 243477                                NaN        johnnyjohnny
# 247942                                NaN             Grimace
# 250507          {'Platform:': ' PC Disc'}         juan garcia
# 252000          {'Platform:': ' PC Disc'}          Honest One
# 261433          {'Platform:': ' PC Disc'}           l. gaines
# 267021      {'Platform:': ' PC Key Card'}     TERESA R NOURIE
# 278156     {'Platform:': ' Mac Download'}          D L Martin
# 285129      {'Platform:': ' PC Download'}    bigger is better
# 289677      {'Platform:': ' PC/Mac Disc'}                Zoey
# 312590      {'Platform:': ' PC Download'}                  JW
# 313722      {'Platform:': ' PC Download'}                Mary
# 316636                                NaN           Trickie10
# 318638     {'Style:': ' USB Flash Drive'}              bredon
# 321775                                NaN             Madalyn
# 328270                                NaN     Amazon Customer
# 330604                                NaN           Stewart R
# 330880                                NaN           Mag130-14
# 337546     {'Platform:': ' Mac Download'}                BATS
# 344179      {'Platform:': ' PC Download'}  Frances E Thomason
# 362289             {'Format:': ' CD-ROM'}     Amazon Customer
# 364755          {'Platform:': ' PC Disc'}      Carlos valdes
# 365655                                NaN              Justis
# 370974             {'Format:': ' CD-ROM'}    Eric Pikcilingis
# 373276                                NaN          Jessica C.
# 376001                                NaN   Douglas W Steever
# 383442                                NaN        Fritocheetos
# 388610                                NaN        Ronald Banks
# 399971                                NaN         Captain Tom
# 406664                                NaN        Lisa Simmons
# 421085                                NaN            tkno boy
# 434276                                NaN               Tarik
# 442679                                NaN     Amazon Customer
# 446926   {'Platform:': ' PC Online Code'}     Amazon Customer
# 449948                                NaN       Peter Bohning
# 453877                                NaN     Amazon Customer
# 457408                                NaN       Chris ruffing
#
#                                                reviewText summary  \
# 5467    I know little about computers. I wanted to be ...     NaN
# 6116    Microsoft Publisher 2002 contains new features...     NaN
# 16504   I know little about computers. I wanted to be ...     NaN
# 31221   I know little about computers. I wanted to be ...     NaN
# 51457   I know little about computers. I wanted to be ...     NaN
# 56135   First of all, I want to say that the quality o...     NaN
# 59963   I know little about computers. I wanted to be ...     NaN
# 64641   First of all, I want to say that the quality o...     NaN
# 68884                                     Fully satisfied     NaN
# 128674  The devil you know is better than the devil yo...     NaN
# 135871  It makes writing 11-16 page papers a lot easie...     NaN
# 176437                                           Love it!     NaN
# 178030                                         Five stars     NaN
# 199350  Is don't understand why people are afraid to g...     NaN
# 203669                                  Love this program     NaN
# 210292  THIS IS  A BIG JOKE.....I GOT IT IN THE MAIL A...     NaN
# 212788                                     Love My Norton     NaN
# 218590  The software work fine for two returns however...     NaN
# 233152  I really like it!!  A lot of repeat music thou...     NaN
# 233182  I purchased approx. 100's of $'s  on the old a...     NaN
# 243477  just tried your new version 12, and truthfully...     NaN
# 247942  Says made in USA ON ENVELOPE: cd says made in ...     NaN
# 250507  Was reccommended by a friend who works in the ...     NaN
# 252000  IT DOESN'T WORK  WITH  WINDOWS 10 .  WHAT A WA...     NaN
# 261433  I would have given it minus one if I could hav...     NaN
# 267021  I am giving this one star because I am unable ...     NaN
# 278156  Be aware this product, while offered at a good...     NaN
# 285129  I agree with so many other reviews.  I, too, w...     NaN
# 289677                                 very gud my frend      NaN
# 312590                   Read now more like I used to do.     NaN
# 313722  The app stalls and pauses.  I was very disappo...     NaN
# 316636                  Does not work on my older kindle.     NaN
# 318638  It's windows, it's annoying and tedious and in...     NaN
# 321775  Awesome game really fun and it helped me learn...     NaN
# 328270                                                NaN     NaN
# 330604  Software is Cool , but over time a corrupted F...     NaN
# 330880                                         Works fine     NaN
# 337546                                     Easy install!!     NaN
# 344179   Did not work as previous versions . Disappointed     NaN
# 362289                                     Yay! I love it     NaN
# 364755                                          Super fun     NaN
# 365655  It was good but was not what I need. I didn't ...     NaN
# 370974  New issues and this stuff hangs... READ FORUMS...     NaN
# 373276  I can't get this game to work on any of my pla...     NaN
# 376001                                                NaN     NaN
# 383442  I've been working at a company that uses GM 6....     NaN
# 388610  Bought when I didn't have my own FAX machine. ...     NaN
# 399971  Great Tutorial But....\n\nPurchased the Profes...     NaN
# 406664  Everything is great, but the Hooked on Phonics...     NaN
# 421085      Doesn't work with modern versions of windows.     NaN
# 434276                                              Great     NaN
# 442679                                                NaN     NaN
# 446926                                                NaN     NaN
# 449948                                                NaN     NaN
# 453877                                                NaN     NaN
# 457408  This is an amazing game. I would give it 10 st...     NaN
#
#         unixReviewTime vote                                              image
# 5467        1188345600    3                                                NaN
# 6116        1015459200   38                                                NaN
# 16504       1188345600  NaN                                                NaN
# 31221       1188345600  NaN                                                NaN
# 51457       1188345600    3                                                NaN
# 56135       1214524800    6                                                NaN
# 59963       1188345600    3                                                NaN
# 64641       1214524800    6                                                NaN
# 68884       1428710400  NaN                                                NaN
# 128674      1386633600  NaN                                                NaN
# 135871      1414108800  NaN                                                NaN
# 176437      1513123200  NaN                                                NaN
# 178030      1481932800  NaN                                                NaN
# 199350      1403136000  NaN                                                NaN
# 203669      1411084800  NaN                                                NaN
# 210292      1418169600  NaN                                                NaN
# 212788      1426723200  NaN                                                NaN
# 218590      1393804800  NaN                                                NaN
# 233152      1492473600  NaN                                                NaN
# 233182      1489536000  NaN                                                NaN
# 243477      1397088000   14                                                NaN
# 247942      1504051200  NaN                                                NaN
# 250507      1418428800  NaN                                                NaN
# 252000      1463616000  NaN                                                NaN
# 261433      1414972800   33                                                NaN
# 267021      1428537600  NaN                                                NaN
# 278156      1421625600  NaN                                                NaN
# 285129      1423699200    8                                                NaN
# 289677      1485129600  NaN                                                NaN
# 312590      1448582400  NaN                                                NaN
# 313722      1438128000  NaN                                                NaN
# 316636      1476489600  NaN                                                NaN
# 318638      1502582400  NaN                                                NaN
# 321775      1461628800  NaN                                                NaN
# 328270      1481241600  NaN                                                NaN
# 330604      1466035200  NaN                                                NaN
# 330880      1504569600  NaN                                                NaN
# 337546      1492214400  NaN                                                NaN
# 344179      1510790400  NaN                                                NaN
# 362289      1493337600  NaN                                                NaN
# 364755      1493078400  NaN                                                NaN
# 365655      1445644800  NaN                                                NaN
# 370974      1155168000  NaN                                                NaN
# 373276      1509321600  NaN                                                NaN
# 376001      1437004800  NaN                                                NaN
# 383442      1144972800    9                                                NaN
# 388610      1391644800  NaN                                                NaN
# 399971      1227225600    7                                                NaN
# 406664      1505779200  NaN                                                NaN
# 421085      1423094400  NaN                                                NaN
# 434276      1432425600  NaN  [https://images-na.ssl-images-amazon.com/image...
# 442679      1530748800  NaN                                                NaN
# 446926      1531612800  NaN                                                NaN
# 449948      1515369600  NaN                                                NaN
# 453877      1530748800  NaN                                                NaN
# 457408      1465603200  NaN                                                NaN

# %% [markdown]
# Whilst looking through the review texts with the missing summary, it is noticeable that there is a customer who has repeatably entered the same text for different products.

# %%
kellyC = df[df['reviewerID'] == 'AGZDSR4R8SA2S'] 
print(kellyC)
# Out:
#        overall  verified   reviewTime     reviewerID        asin style  \
# 5467         5      True  08 29, 2007  AGZDSR4R8SA2S  B000050ZRE   NaN
# 16504        5      True  08 29, 2007  AGZDSR4R8SA2S  B0001FS9NE   NaN
# 31221        5      True  08 29, 2007  AGZDSR4R8SA2S  B000EORV8Q   NaN
# 51457        5      True  08 29, 2007  AGZDSR4R8SA2S  B0000AZJY6   NaN
# 59963        5      True  08 29, 2007  AGZDSR4R8SA2S  B0000AZJY6   NaN
#
#         reviewerName                                         reviewText  \
# 5467   Kelly Carlson  I know little about computers. I wanted to be ...
# 16504  Kelly Carlson  I know little about computers. I wanted to be ...
# 31221  Kelly Carlson  I know little about computers. I wanted to be ...
# 51457  Kelly Carlson  I know little about computers. I wanted to be ...
# 59963  Kelly Carlson  I know little about computers. I wanted to be ...
#
#       summary  unixReviewTime vote image
# 5467      NaN      1188345600    3   NaN
# 16504     NaN      1188345600  NaN   NaN
# 31221     NaN      1188345600  NaN   NaN
# 51457     NaN      1188345600    3   NaN
# 59963     NaN      1188345600    3   NaN

# %%
kellyCReview = df[df['reviewerID'] == 'AGZDSR4R8SA2S'].sum()

# %%
print(kellyCReview)
# Out:
# overall                                                          25
# verified                                                          5
# reviewTime        08 29, 200708 29, 200708 29, 200708 29, 200708...
# reviewerID        AGZDSR4R8SA2SAGZDSR4R8SA2SAGZDSR4R8SA2SAGZDSR4...
# asin              B000050ZREB0001FS9NEB000EORV8QB0000AZJY6B0000A...
# style                                                             0
# reviewerName      Kelly CarlsonKelly CarlsonKelly CarlsonKelly C...
# reviewText        I know little about computers. I wanted to be ...
# summary                                                           0
# unixReviewTime                                           5941728000
# image                                                             0
# dtype: object

# %%
df[df['reviewerID']=='AGZDSR4R8SA2S']['reviewText']
# Out:
# 5467     I know little about computers. I wanted to be ...
# 16504    I know little about computers. I wanted to be ...
# 31221    I know little about computers. I wanted to be ...
# 51457    I know little about computers. I wanted to be ...
# 59963    I know little about computers. I wanted to be ...
# Name: reviewText, dtype: object

# %% [markdown]
# When taking a closer look it appears that the text is identical for multiple products.

# %%
#Review for a WIFI extender
df.iloc[16504]['reviewText']
# Out:
# "I know little about computers. I wanted to be able to use the desktop without having to have our wireless router on all the time. Ordered this, at first it scared me that there was really no instructions. I plugged in the Cat5 from the cable box, ran one cat 5 to desktop, one to wireless router, turned it all back on, and everything works!!! If it's easy enough that I can do it, anyone can. <G>"

# %%
#Review for a 4port HUB
df.iloc[31221]['reviewText']
# Out:
# "I know little about computers. I wanted to be able to use the desktop without having to have our wireless router on all the time. Ordered this, at first it scared me that there was really no instructions. I plugged in the Cat5 from the cable box, ran one cat 5 to desktop, one to wireless router, turned it all back on, and everything works!!! If it's easy enough that I can do it, anyone can. <G>"

# %%
#checking the time of the reviews
from datetime import datetime, timedelta

unix_ts = 1188345600
reviewTime = (datetime.fromtimestamp(unix_ts) - timedelta(hours=2)).strftime('%Y-%m-%d %H:%M:%S')
print(reviewTime)
# Out:
# 2007-08-29 00:00:00

# %% [markdown]
# This is probably not a real review from a real customer, as all reviews have been made at the same time and are identical.
# However with dropping the empty values in the columns containing text, these will also be removed.

# %%
# dropping rows with empty values in either of the two columns
df.dropna(how='any', subset=['reviewText', 'summary'], axis=0, inplace=True)

# %%
# checking if there are any null values left
df.isnull().sum()
# Out:
# overall                0
# verified               0
# reviewTime             0
# reviewerID             0
# asin                   0
# style             224977
# reviewerName          24
# reviewText             0
# summary                0
# unixReviewTime         0
# vote              331479
# image             457822
# dtype: int64

# %% [markdown]
# ### Sentiment Analysis

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

#create SID object
sid = SentimentIntensityAnalyzer()

# %%
#polarity score analysis on the reviewText column
df['scores'] = df['reviewText'].apply(lambda review:sid.polarity_scores(review))

# %%
#polarity score analysis on the summary column
df['summary_scores'] = df['summary'].apply(lambda review:sid.polarity_scores(review))

# %% [markdown]
# The next step would be to make the results visible including only the overal score from 5 to 1 and the scores of the columns 'reviewText' in 'scores' and 'summary' in 'summary_scores'.

# %%
# show results of the polarity score analysis
df[['overall', 'scores', 'summary_scores']].head()
# Out:
#    overall                                             scores  \
# 0        4  {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'comp...
# 1        4  {'neg': 0.0, 'neu': 0.89, 'pos': 0.11, 'compou...
# 2        1  {'neg': 0.123, 'neu': 0.837, 'pos': 0.04, 'com...
# 3        3  {'neg': 0.139, 'neu': 0.786, 'pos': 0.074, 'co...
# 4        5  {'neg': 0.0, 'neu': 0.868, 'pos': 0.132, 'comp...
#
#                                       summary_scores
# 0  {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'comp...
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3  {'neg': 0.736, 'neu': 0.264, 'pos': 0.0, 'comp...
# 4  {'neg': 0.0, 'neu': 0.471, 'pos': 0.529, 'comp...

# %%
# create the compound values for better understanding

df['compoundRev']  = df['scores'].apply(lambda score_dict: score_dict['compound'])
df['compoundSum']  = df['scores'].apply(lambda score_dict: score_dict['compound'])

# %%
df[['overall', 'scores', 'summary_scores', 'compoundRev', 'compoundSum']].head()
# Out:
#    overall                                             scores  \
# 0        4  {'neg': 0.0, 'neu': 0.802, 'pos': 0.198, 'comp...
# 1        4  {'neg': 0.0, 'neu': 0.89, 'pos': 0.11, 'compou...
# 2        1  {'neg': 0.123, 'neu': 0.837, 'pos': 0.04, 'com...
# 3        3  {'neg': 0.139, 'neu': 0.786, 'pos': 0.074, 'co...
# 4        5  {'neg': 0.0, 'neu': 0.868, 'pos': 0.132, 'comp...
#
#                                       summary_scores  compoundRev  compoundSum
# 0  {'neg': 0.0, 'neu': 0.196, 'pos': 0.804, 'comp...       0.6870       0.6870
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.5709       0.5709
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...      -0.7307      -0.7307
# 3  {'neg': 0.736, 'neu': 0.264, 'pos': 0.0, 'comp...      -0.3753      -0.3753
# 4  {'neg': 0.0, 'neu': 0.471, 'pos': 0.529, 'comp...       0.9380       0.9380

# %%
df[['overall', 'compoundRev', 'compoundSum']].head()
# Out:
#    overall  compoundRev  compoundSum
# 0        4       0.6870       0.6870
# 1        4       0.5709       0.5709
# 2        1      -0.7307      -0.7307
# 3        3      -0.3753      -0.3753
# 4        5       0.9380       0.9380

# %% [markdown]
# The compound values seem to be equal between the actual review text and the summary.
# For better readability the compound will be displayed as a predicted label, either positive or negative.

# %%
# return 'pos' if the compound score is greater than 0, else return 'neg'
df['reviewLabel'] = df['compoundRev'].apply(lambda c: 'pos' if c >=0 else 'neg')
df['summaryLabel'] = df['compoundSum'].apply(lambda c: 'pos' if c >=0 else 'neg')

# %%
df[['overall', 'compoundRev', 'compoundSum', 'reviewLabel', 'summaryLabel']].head(20)
# Out:
#     overall  compoundRev  compoundSum reviewLabel summaryLabel
# 0         4       0.6870       0.6870         pos          pos
# 1         4       0.5709       0.5709         pos          pos
# 2         1      -0.7307      -0.7307         neg          neg
# 3         3      -0.3753      -0.3753         neg          neg
# 4         5       0.9380       0.9380         pos          pos
# 5         4       0.7184       0.7184         pos          pos
# 6         3       0.4404       0.4404         pos          pos
# 7         5       0.8399       0.8399         pos          pos
# 8         5       0.8955       0.8955         pos          pos
# 9         5       0.7391       0.7391         pos          pos
# 10        2       0.9741       0.9741         pos          pos
# 11        5       0.3818       0.3818         pos          pos
# 12        2       0.3682       0.3682         pos          pos
# 13        3       0.3466       0.3466         pos          pos
# 14        4       0.9447       0.9447         pos          pos
# 15        5       0.8685       0.8685         pos          pos
# 16        5       0.7351       0.7351         pos          pos
# 17        2       0.0000       0.0000         pos          pos
# 18        1      -0.3089      -0.3089         neg          neg
# 19        1       0.9312       0.9312         pos          pos

# %% [markdown]
# It appears that the review text and the summary both display the same values and show both either positive or negative.
# However compared to the overall score left by the customers, the sentiment score does not always match. It seems that there is a match on the higher scores such as 4 and 5, but the lower overall scores are quite mixed and can be both negative or positive.

# %% [markdown]
# ### Evaluating Accuracy

# %% [markdown]
# To compare the results of the prediction against the overall score left by the customers, I will have to go a step back and return the predicted scores into numeric labels from 5 to 1.

# %%
# list of conditions
conditions = [
    (df['compoundRev'] < 1.0) & (df['compoundRev'] >= 0.8),
    (df['compoundRev'] < 0.8) & (df['compoundRev'] >= 0.6),
    (df['compoundRev'] < 0.6) & (df['compoundRev'] >= 0.4),
    (df['compoundRev'] < 0.4) & (df['compoundRev'] >= 0.2),
    (df['compoundRev'] < 0.2)
    ]

# list of assigned values for each condition
values = [5, 4, 3, 2, 1]

# assign values to the new column by using np.select()
df['newLabel'] = np.select(conditions, values)

# %%
df[['overall', 'compoundRev', 'newLabel']].head(20)
# Out:
#     overall  compoundRev  newLabel
# 0         4       0.6870         4
# 1         4       0.5709         3
# 2         1      -0.7307         1
# 3         3      -0.3753         1
# 4         5       0.9380         5
# 5         4       0.7184         4
# 6         3       0.4404         3
# 7         5       0.8399         5
# 8         5       0.8955         5
# 9         5       0.7391         4
# 10        2       0.9741         5
# 11        5       0.3818         2
# 12        2       0.3682         2
# 13        3       0.3466         2
# 14        4       0.9447         5
# 15        5       0.8685         5
# 16        5       0.7351         4
# 17        2       0.0000         1
# 18        1      -0.3089         1
# 19        1       0.9312         5

# %% [markdown]
# A first look at the two columns shows that not all new labels, which were calculated based on the text analysis match the rating of the customers.
# It would be interesting to evaluate the accuracy score.

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
accuracy_score(df['newLabel'],df['overall'])
# Out:
# 0.36623704606810065

# %% [markdown]
# As expected the overall accuracy is with about 0.37 quite low.

# %%
# classification report
print(classification_report(df['newLabel'],df['overall']))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.64      0.45      0.53    146757
#            2       0.08      0.08      0.08     31294
#            3       0.12      0.08      0.09     58284
#            4       0.19      0.16      0.18     85921
#            5       0.39      0.60      0.47    137064
#
#     accuracy                           0.37    459320
#    macro avg       0.28      0.27      0.27    459320
# weighted avg       0.37      0.37      0.36    459320

# %%
# confusion matrix
print(confusion_matrix(df['newLabel'],df['overall']))
# Out:
# [[65482 17158 16443 15862 31812]
#  [ 6942  2361  3783  5958 12250]
#  [ 8228  2712  4566 10945 31833]
#  [ 8829  3281  5095 14024 54692]
#  [13047  5930  9503 26797 81787]]

# %% [markdown]
# ### Explanation

# %%
df.iloc[19]['reviewText']
# Out:
# "Disappointing textbook. To start, the lack of color is dismal, but of less importance. However, from a MARKETING book, I expected it to be a little more eye-grabbing.\nMore importantly this book regularly cites wikipedia as a source, and I caught at least two examples of incorrect information when discussing how companies fit certain profiles. In one example it states that Kit Kat is a Nestle brand when it is produced by Hershey's. It also uses companies as examples that have long since been bought out by other companies. While neither of these two items errodes the core idea of marketing, they were just easily spotted. It makes it difficult to trust the core information when something so simple as a little research could correct these errors. Along with the wikipedia citing, I don't know that I would trust this source as 'authoritive'"

# %%
df.iloc[10]['reviewText']
# Out:
# "Maybe it's just me (I have no marketing background but desperately want to learn for my start-up) but I cannot get hardly anything out of this text. I have tried very hard to tread through the writing and learn something useful but chapter after chapter seems to be the exact same thing... overly wordy, rambling & unnecessarily academic writing with no comprehensible message behind it, no strategies I can apply to my own business and no organization that I can make sense of. Feels almost like I'm reading a paper a college student BSed their way through with a whole bunch of long words and cryptic sentences in order to sound impressive. What a rip-off. I paid $70 for this and it has been the most useless book I've paid for in my research process (and I've read 16 other books thus far to help me with my venture).\n\nThe only reason I'm giving this two stars and not one star is that out of the first six chapters I've read, two of them actually made sense. One was on International Marketing and did a very good job explaining the technology limitations of other countries and the ways foreign citizens adapt to this and use technology. This is actually very helpful information and I'm going to use it. The second was on the legal and ethical aspects of using the internet. It gave an extremely concise explanation with lots of info and it was easily understandable. Unfortunately, I've read a chapter like this over and over and over again in pretty much every e-business book I've picked up so far so it's getting old."

# %% [markdown]
# In both cases the criticism in the review is expressed in the tone and by giving examples. Therefore the use of neutral or words classified as positive will outweigh the clearly negative expressions.
#
# In the example the reviewer makes a point of how bad the text is by highlighting the only two things that were good about the book. Expressions like "did a very good job explaining" or "very helpful information" wich in human interaction can easily be understood within the context as the exception of the norm, will have the opposite effect on the computed analysis.
#
# As an example of what can be understood as negative, is the review with the index number 2.

# %%
df.iloc[2]['reviewText']
# Out:
# 'IF YOU ARE TAKING THIS CLASS DON"T WASTE YOUR MONEY ON THIS SO CALLED BOOK! $140.00 FOR A "BOOK" THAT ISIN\'T EVEN BOUND LOOSE LEAFS, THAT I HAD TO PROVIDE MY OWN BINDER FOR. TURNS OUT YOU CAN BUY ACCESS TO THE BOOK AT MCGRAW HILL CONNECT CORE FOR $70.00\n\nTHIS BOOK IS A COMPLETE WASTE OF MONEY!'
